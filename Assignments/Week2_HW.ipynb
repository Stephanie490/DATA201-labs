# %% [markdown]
# <a href="https://colab.research.google.com/github/Stephanie490/DATA201-labs/blob/main/Assignments/Week2_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Question 8 Loading College dataset
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
College = pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/College.csv")

# %%
import pandas as pd

# Load dataset
College = pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/College.csv")

# Fix the misspelled column name and rename it
college3 = College.rename({'Unnamed: 0': 'College'}, axis=1)

# Set the new column as the index
college3 = college3.set_index('College')

# %%
# Question 9 Loading Auto dataset

# %%
import pandas as pd
Auto = pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/Auto.csv")

# %%
# Question 10 Loading Boston dataset

# %%
import pandas as pd
Boston = pd.read_csv("/content/drive/MyDrive/Data_201/Datasets/Boston.csv")
